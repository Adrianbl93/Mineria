# %% [markdown]
# ## Clase 2 Wranling Code

# %%
import pandas as pd
import numpy as np

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %ls datasets/datasets
# Out:
# adult.csv                  census.csv     nhanes_2015_2016.csv
# airline_data.csv           coches.csv     pokemon.csv
# antropometria00.csv        cwurData.csv   reg_data.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          movies.csv

# %%
df= pd.read_excel('datasets/datasets/Canada.xlsx',
                 sheet_name = 'Canada by Citizenship',
                 skiprows = range(20),
                 skipfooter =2,
                 engine = 'openpyxl')

# %%
df.head(5)
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df.columns
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')

# %%
#df.setoption('display.max_columns', None)
#df.setoption('display.max_rows', None)

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Columns: 43 entries, Type to 2013
# dtypes: int64(37), object(6)
# memory usage: 65.6+ KB

# %%
df.shape
# Out:
# (195, 43)

# %%
df.drop(['Type', 'Coverage',     'AREA',       'REG',  'DevName'],
        axis =1,
        inplace = True
       )
       #inplace=true replace df
        # axis 0 rows, axis 1 columns

# %%
df.rename(columns={'OdName': 'Country', 'AreaName': 'Continent',},
          inplace = True
         )

df.head(2)
# Out:
#        Country Continent          RegName  DEV  1980  1981  1982  1983  1984  \
# 0  Afghanistan      Asia    Southern Asia  902    16    39    39    47    71
# 1      Albania    Europe  Southern Europe  901     1     0     0     0     0
#
#    1985  ...  2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# 0   340  ...  2978  3436  3009  2652  2111  1746  1758  2203  2635  2004
# 1     0  ...  1450  1223   856   702   560   716   561   539   620   603
#
# [2 rows x 38 columns]

# %%
df['Total']=df.iloc[:,3:].sum(axis=1)

# %% [markdown]
# iloc number, loc text

# %%
df.head(2)
# Out:
#        Country Continent          RegName  DEV  1980  1981  1982  1983  1984  \
# 0  Afghanistan      Asia    Southern Asia  902    16    39    39    47    71
# 1      Albania    Europe  Southern Europe  901     1     0     0     0     0
#
#    1985  ...  2005  2006  2007  2008  2009  2010  2011  2012  2013  Total
# 0   340  ...  3436  3009  2652  2111  1746  1758  2203  2635  2004  59541
# 1     0  ...  1223   856   702   560   716   561   539   620   603  16600
#
# [2 rows x 39 columns]

# %%
df[df['Country'] ==  'Japan']
# Out:
#    Country Continent       RegName  DEV  1980  1981  1982  1983  1984  1985  \
# 87   Japan      Asia  Eastern Asia  901   701   756   598   309   246   198
#
#     ...  2005  2006  2007  2008  2009  2010  2011  2012  2013  Total
# 87  ...  1067  1212  1250  1284  1194  1168  1265  1214   982  28608
#
# [1 rows x 39 columns]

# %%
df.query('Country in ("Japan", "Albania")')
# Out:
#     Country Continent          RegName  DEV  1980  1981  1982  1983  1984  \
# 1   Albania    Europe  Southern Europe  901     1     0     0     0     0
# 87    Japan      Asia     Eastern Asia  901   701   756   598   309   246
#
#     1985  ...  2005  2006  2007  2008  2009  2010  2011  2012  2013  Total
# 1      0  ...  1223   856   702   560   716   561   539   620   603  16600
# 87   198  ...  1067  1212  1250  1284  1194  1168  1265  1214   982  28608
#
# [2 rows x 39 columns]

# %%
df.set_index('Country',
             inplace = True)
df.head(2)
# Out:
#             Continent          RegName  DEV  1980  1981  1982  1983  1984  \
# Country
# Afghanistan      Asia    Southern Asia  902    16    39    39    47    71
# Albania        Europe  Southern Europe  901     1     0     0     0     0
#
#              1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# Country                  ...
# Afghanistan   340   496  ...  3436  3009  2652  2111  1746  1758  2203  2635
# Albania         0     1  ...  1223   856   702   560   716   561   539   620
#
#              2013  Total
# Country
# Afghanistan  2004  59541
# Albania       603  16600
#
# [2 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['Continent',   'RegName',       'DEV',        1980,        1981,
#               1982,        1983,        1984,        1985,        1986,
#               1987,        1988,        1989,        1990,        1991,
#               1992,        1993,        1994,        1995,        1996,
#               1997,        1998,        1999,        2000,        2001,
#               2002,        2003,        2004,        2005,        2006,
#               2007,        2008,        2009,        2010,        2011,
#               2012,        2013,     'Total'],
#       dtype='object')

# %%
df.index.name=None

# %%
df.loc['Japan']
# Out:
# Continent            Asia
# RegName      Eastern Asia
# DEV                   901
# 1980                  701
# 1981                  756
# 1982                  598
# 1983                  309
# 1984                  246
# 1985                  198
# 1986                  248
# 1987                  422
# 1988                  324
# 1989                  494
# 1990                  379
# 1991                  506
# 1992                  605
# 1993                  907
# 1994                  956
# 1995                  826
# 1996                  994
# 1997                  924
# 1998                  897
# 1999                 1083
# 2000                 1010
# 2001                 1092
# 2002                  806
# 2003                  817
# 2004                  973
# 2005                 1067
# 2006                 1212
# 2007                 1250
# 2008                 1284
# 2009                 1194
# 2010                 1168
# 2011                 1265
# ...

# %%
df.loc[['Japan','Albania']]
# Out:
#         Continent          RegName  DEV  1980  1981  1982  1983  1984  1985  \
# Japan        Asia     Eastern Asia  901   701   756   598   309   246   198
# Albania    Europe  Southern Europe  901     1     0     0     0     0     0
#
#          1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  2013  \
# Japan     248  ...  1067  1212  1250  1284  1194  1168  1265  1214   982
# Albania     1  ...  1223   856   702   560   716   561   539   620   603
#
#          Total
# Japan    28608
# Albania  16600
#
# [2 rows x 38 columns]

# %%
df.columns = list(map(str,df.columns))
#chance columns to strings

# %%
df[df.index == 'Japan']
# Out:
#       Continent       RegName  DEV  1980  1981  1982  1983  1984  1985  1986  \
# Japan      Asia  Eastern Asia  901   701   756   598   309   246   198   248
#
#        ...  2005  2006  2007  2008  2009  2010  2011  2012  2013  Total
# Japan  ...  1067  1212  1250  1284  1194  1168  1265  1214   982  28608
#
# [1 rows x 38 columns]

# %%
df.loc['Japan','2000']
# Out:
# 1010

# %%
condition = df['Continent']=='Asia'
print(condition)
# Out:
# Afghanistan        True
# Albania           False
# Algeria           False
# American Samoa    False
# Andorra           False
#                   ...
# Viet Nam           True
# Western Sahara    False
# Yemen              True
# Zambia            False
# Zimbabwe          False
# Name: Continent, Length: 195, dtype: bool

# %%
nDf = df [condition & (df['RegName']=='Southern Asia')]
nDf.describe()
# Out:
#          DEV         1980         1981         1982         1983         1984  \
# count    9.0     9.000000     9.000000     9.000000     9.000000     9.000000
# mean   902.0  1257.222222  1285.111111  1287.888889  1128.555556  1067.444444
# std      0.0  2893.967207  2815.988922  2652.848160  2392.058481  1865.123194
# min    902.0     0.000000     0.000000     0.000000     0.000000     0.000000
# 25%    902.0     1.000000     1.000000     6.000000     1.000000     2.000000
# 50%    902.0    83.000000    84.000000    86.000000    81.000000    98.000000
# 75%    902.0   978.000000   972.000000  1201.000000   900.000000  1086.000000
# max    902.0  8880.000000  8670.000000  8147.000000  7338.000000  5704.000000
#
#               1985         1986          1987          1988  ...  \
# count     9.000000     9.000000      9.000000      9.000000  ...
# mean    850.444444  1385.333333   2216.333333   2247.222222  ...
# std    1371.195839  2275.046868   3359.087674   3681.604093  ...
# ...

# %%
nDf.head(2)
# Out:
#             Continent        RegName  DEV  1980  1981  1982  1983  1984  1985  \
# Afghanistan      Asia  Southern Asia  902    16    39    39    47    71   340
# Bangladesh       Asia  Southern Asia  902    83    84    86    81    98    92
#
#              1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  2013  \
# Afghanistan   496  ...  3436  3009  2652  2111  1746  1758  2203  2635  2004
# Bangladesh    486  ...  4171  4014  2897  2939  2104  4721  2694  2640  3789
#
#              Total
# Afghanistan  59541
# Bangladesh   66470
#
# [2 rows x 38 columns]

# %%
df1 = pd.DataFrame ({'a':[1,3,5,7,9],
                    'b':['one','three','five','seven','nine']
                   }
                  )

# %%
df2 = pd.DataFrame({'c':[2,4,6,8,10],
                    'd':['Two', 'Four', 'six', 'eight', 'ten']
                   }
                  )

# %%
df3 = pd.concat([df1,df2],
                axis=1)

# %%
df3
# Out:
#    a      b   c      d
# 0  1    one   2    Two
# 1  3  three   4   Four
# 2  5   five   6    six
# 3  7  seven   8  eight
# 4  9   nine  10    ten

# %%
x=  pd.DataFrame ({'a':[2,np.nan,3,8],
                    'b':[4,5,7,8],
                   'c':[2,4,np.nan,8]
                   }
                  )

# %%
df1=x
df2=x
df3=x

# %%
df1
# Out:
#      a  b    c
# 0  2.0  4  2.0
# 1  NaN  5  4.0
# 2  3.0  7  NaN
# 3  8.0  8  8.0

# %%
df3
# Out:
#      a  b    c
# 0  2.0  4  2.0
# 1  NaN  5  4.0
# 2  3.0  7  NaN
# 3  8.0  8  8.0

# %%
df3.dropna()
# Out:
#      a  b    c
# 0  2.0  4  2.0
# 3  8.0  8  8.0

# %%
df3
# Out:
#      a  b    c
# 0  2.0  4  2.0
# 1  NaN  5  4.0
# 2  3.0  7  NaN
# 3  8.0  8  8.0

# %%
df1.dropna(axis=0,
         inplace=True)
df1
# Out:
#      a  b    c
# 0  2.0  4  2.0
# 3  8.0  8  8.0

# %%
df2.dropna(axis=1,
         inplace=True)
df2
# Out:
#    b
# 0  4
# 1  5
# 2  7
# 3  8

# %%
df3
# Out:
#    a      b   c      d
# 0  1    one   2    Two
# 1  3  three   4   Four
# 2  5   five   6    six
# 3  7  seven   8  eight
# 4  9   nine  10    ten

# %%
df3['Total']= df3.sum(numeric_only = True,
                        axis = 1)

# %%
df3.loc['Total']= df3.sum(numeric_only = True,
                        axis = 0)

# %%
df3.loc['Total']= df3.sum(axis = 0)

# %%
df3
# Out:
#    a      b   c      d  Total
# 0  1    one   2    Two      3
# 1  3  three   4   Four      7
# 2  5   five   6    six     11
# 3  7  seven   8  eight     15
# 4  9   nine  10    ten     19
