# %%
# %ls
# Out:
# datasets-20220420T233904Z-001/  README.md  requirements.txt  Untitled.ipynb

# %%
# %ls datasets/datasets/
# Out:
# adult.csv                  census.csv     nhanes_2015_2016.csv
# airline_data.csv           coches.csv     pokemon.csv
# antropometria00.csv        cwurData.csv   reg_data.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          movies.csv

# %% [markdown]
# # Variable Types

# %%
type(None)
# Out:
# NoneType

# %%
import pandas as pd
import math

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
aList = [2,3,4,5]

# %%
aList
# Out:
# [2, 3, 4, 5]

# %%
print(*aList)
# Out:
# 2 3 4 5

# %%
for i in aList:
    print(i, '\t', type(i))
# Out:
# 2 	 <class 'int'>
# 3 	 <class 'int'>
# 4 	 <class 'int'>
# 5 	 <class 'int'>

# %%
number = [1,2,3,4, math.pi]
number
# Out:
# [1, 2, 3, 4, 3.141592653589793]

# %%
sum(number)
# Out:
# 13.141592653589793

# %%
len(number)
# Out:
# 5

# %%
sum(number)/len(number)
# Out:
# 2.6283185307179586

# %%
type(sum(number))
# Out:
# float

# %%
3**10
# Out:
# 59049

# %%
6*10**(-1)
# Out:
# 0.6000000000000001

# %%
(6*10)**(-1)
# Out:
# 0.016666666666666666

# %% [markdown]
# # Variable Type

# %% [markdown]
# 1. Numerical
# 2. Categorical

# %%
'2012'*3
# Out:
# '201220122012'

# %%
x=5
y=7
if x < y:
    print('{} is less than {}'.format(x,y))
else:
    print('x is greatar than y')
# Out:
# 5 is less than 7

# %%
booList = [True, 6>10, 1==3, None is None]

# %%
bList = ['d','a','b','c']
bList.sort()
bList[:2]
bList[2:]
# Out:
# ['c', 'd']

# %%
# %ls datasets/datasets
# Out:
# adult.csv                  census.csv     nhanes_2015_2016.csv
# airline_data.csv           coches.csv     pokemon.csv
# antropometria00.csv        cwurData.csv   reg_data.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          movies.csv

# %%
path = 'datasets/datasets/Cartwheeldata.csv'
df = pd.read_csv(path)
df
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
x= df.columns
x=x.tolist()
x.sort()
x
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %% [markdown]
# # loc and iloc
#
# ## loc
#     df.Loc[rowStart:rowEnd, ColumnStart:ColumnEnd] # IDNames
#
# ## iloc
#     df.Loc[rowStart:rowEnd, ColumnStart:ColumnEnd] # ID_Indices

# %%
df.loc[:5,'CWDistance']
# Out:
# 0    79
# 1    70
# 2    85
# 3    87
# 4    72
# 5    81
# Name: CWDistance, dtype: int64

# %%
df.iloc[:5, 8]
# Out:
# 0    79
# 1    70
# 2    85
# 3    87
# 4    72
# Name: CWDistance, dtype: int64

# %%
df.loc[:5,'CWDistance':'Score']
# Out:
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4
# 5          81        N              0      3

# %%
df.loc[:5,['CWDistance','Score']]
# Out:
#    CWDistance  Score
# 0          79      7
# 1          70      8
# 2          85      7
# 3          87     10
# 4          72      4
# 5          81      3

# %%
df.Gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df.groupby(['Gender','GenderGroup']).size()
# Out:
# Gender  GenderGroup
# F       1              12
# M       2              13
# dtype: int64
